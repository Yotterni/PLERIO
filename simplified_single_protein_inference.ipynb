# %%
from engine.inference_utils.single_protein_model_inference import PretrainedProteinModel

# %%
model = PretrainedProteinModel(
    protein_name='FASTKD2',
    cell_line='K562',
    weight_path='single_prot_models/K562/FASTKD2/FCNN_model.pt'
)

# %%
model('GGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGG')
# Out:
# array([0.99989486, 0.96870226], dtype=float32)
