# %%
from plerio.engine.inference_utils.single_protein_model_inference import PretrainedProteinModel

# %%
model = PretrainedProteinModel(
    protein_name='FASTKD2',
    cell_line='K562',
    weight_path='single_prot_models/K562/FASTKD2/FCNN_model.pt'
)

# %%
model('AT' * 1000)
# Out:
# array([0.486587, 0.486587, 0.486587, 0.486587, 0.486587, 0.486587,
#        0.486587, 0.486587, 0.486587, 0.486587, 0.486587, 0.486587,
#        0.486587, 0.486587, 0.486587, 0.486587, 0.486587, 0.486587,
#        0.486587, 0.486587, 0.486587, 0.486587, 0.486587, 0.486587,
#        0.486587, 0.486587, 0.486587, 0.486587, 0.486587, 0.486587,
#        0.486587, 0.486587, 0.486587, 0.486587, 0.486587, 0.486587,
#        0.486587], dtype=float32)
